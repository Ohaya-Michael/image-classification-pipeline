# %%
from S3_package_for_subArticle import *

# %%
generate_augmented_dataset("flower_photos", 1, 240)
# Out:
# ...
# 100%|██████████| 799/799 [00:05<00:00, 141.38it/s]

# %%
split_to_train_test_valid("flower_photos")
# Out:
# Copying files: 9577 files [00:05, 1619.79 files/s]

# %%
train_dataset, test_dataset, valid_dataset = prepare_flow_from_dir_dataset("output")
# Out:
# Found 6701 files belonging to 5 classes.
# Found 484 files belonging to 5 classes.
# Found 2392 files belonging to 5 classes.

# %%
base_model_fine, model_fine, history_fine = buildEfficientB0_Model(train_dataset, valid_dataset, 5, 10, 10)
# Out:
# Extracting features using pretrained model ...
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/10
# 419/419 - 104s - 248ms/step - accuracy: 0.7750 - loss: 0.6322 - val_accuracy: 0.8863 - val_loss: 0.3386
# Epoch 2/10
# 419/419 - 126s - 301ms/step - accuracy: 0.8538 - loss: 0.4101 - val_accuracy: 0.8946 - val_loss: 0.3017
# Epoch 3/10
# 419/419 - 147s - 351ms/step - accuracy: 0.8754 - loss: 0.3524 - val_accuracy: 0.9072 - val_loss: 0.2725
# Epoch 4/10
# 419/419 - 150s - 359ms/step - accuracy: 0.8824 - loss: 0.3309 - val_accuracy: 0.9093 - val_loss: 0.2582
# Epoch 5/10
# 419/419 - 147s - 351ms/step - accuracy: 0.8836 - loss: 0.3175 - val_accuracy: 0.9043 - val_loss: 0.2499
# Epoch 6/10
# 419/419 - 142s - 339ms/step - accuracy: 0.8896 - loss: 0.3046 - val_accuracy: 0.9105 - val_loss: 0.2439
# Epoch 7/10
# ...

# %%
eval = evaluate_model(test_dataset, "buildEfficientB0_Model/trained_model_finetuned.keras")
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 683ms/step - accuracy: 0.9153 - loss: 0.1945

# %%
evaluate_and_predict(test_dataset, "buildEfficientB0_Model/trained_model_finetuned.keras", 16)
# Out:
# Evaluating the model ...
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 653ms/step - accuracy: 0.9153 - loss: 0.1945
# Predicting the model using test dataset ...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 919ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step

# %%
evaluate_and_predict(test_dataset, "buildEfficientB0_Model/trained_model_finetuned.keras", 1)
# Out:
# Evaluating the model ...
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 675ms/step - accuracy: 0.9153 - loss: 0.1945
# Predicting the model using test dataset ...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 904ms/step
